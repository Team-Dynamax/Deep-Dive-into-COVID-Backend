# %%
import pandas as pd
import numpy as np
import firebaseInterface

df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-9beef0ce4300> in <module>
#       3 import firebaseInterface
#       4
# ----> 5 df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')
#       6 df.head()
#
# ...
